# %% [markdown]
# <a href="https://colab.research.google.com/github/nooralotibi/final_project1/blob/main/Copy_of_Untitled59.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python_packages = """pandas
numpy
seaborn
matplotlib """
with open("requirment.txt", "w") as f:
    f.write(python_packages)
print("requirment file is ready")
# Out:
# requirment file is ready
